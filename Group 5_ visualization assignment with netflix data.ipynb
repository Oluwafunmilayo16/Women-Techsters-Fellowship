# %%
#Group 5 members: Data Science and AI
#Juliet Sackey
#Kaouter Labed
#Monica Atuorah
#Naomi Odidi
#Louisa Bonsu
#Oluwafunmilayo Oluyemi
#Kehinde Adebisi
#Nwajiunor Edgar
#Kawthar Oyolola
#Ndidiamaka Eneje

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading/reading the dataset
Netflix_data=pd.read_csv('netflix_titles.csv')
Netflix_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
Netflix_data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
Netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#cleaning the dataset_dropping some colums (eg.date_added)
# dropping the few null rows
Netflix_data = Netflix_data.dropna(subset=['date_added', 'rating', 'duration'])
Netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#cleaning the dataset_filling some rows(eg. diector)
Netflix_data['director']=Netflix_data['director'].fillna('Non specified')
Netflix_data
# Out:
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\3003793227.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data['director']=Netflix_data['director'].fillna('Non specified')
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Non specified
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Non specified
# 4         s5  TV Show           Kota Factory    Non specified
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# ...

# %%
#cleaning the dataset_filling null values(eg cast rolls, country rows)
Netflix_data['cast']=Netflix_data['cast'].fillna('Non listed')
Netflix_data['country']=Netflix_data['country'].fillna('Non specified')
Netflix_data
# Out:
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\4173986087.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data['cast']=Netflix_data['cast'].fillna('Non listed')
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\4173986087.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data['country']=Netflix_data['country'].fillna('Non specified')
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# ...

# %%
#visulaization 
Netflix_data['type'].value_counts()
# Out:
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
#Movie vs TV show 

plt.pie(Netflix_data['type'].value_counts(),
       labels=Netflix_data['type'].value_counts().index,
       colors=('yellow','red'),startangle=60
    
       )

plt.legend();

# %%
#showing the value count for country
Netflix_data['country'].value_counts()
# Out:
# United States                             2809
# India                                      972
# Non specified                              829
# United Kingdom                             418
# Japan                                      243
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 749, dtype: int64

# %%
#To include only TV show in the dataset
Netflix_TV=Netflix_data[Netflix_data['type']=='TV Show']
Netflix_TV
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water    Non specified
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Non specified
# 4         s5  TV Show           Kota Factory    Non specified
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V    Non specified
# 8796   s8797  TV Show             Yunus Emre    Non specified
# 8797   s8798  TV Show              Zak Storm    Non specified
# 8800   s8801  TV Show     Zindagi Gulzar Hai    Non specified
# 8803   s8804  TV Show            Zombie Dumb    Non specified
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
#Top directors for TV show
TV_director=Netflix_TV['director'].str.split(' ',expand=True).stack()
TV_director
# Out:
# 1     0          Non
#       1    specified
# 2     0       Julien
#       1     Leclercq
# 3     0          Non
#              ...
# 8797  1    specified
# 8800  0          Non
#       1    specified
# 8803  0          Non
#       1    specified
# Length: 5513, dtype: object

# %%
TV_director=pd.DataFrame(TV_director)
TV_director.head()
# Out:
#              0
# 1 0        Non
#   1  specified
# 2 0     Julien
#   1   Leclercq
# 3 0        Non

# %%
#Rename the TV_director as Director
TV_director.columns=['Directors']
#Choosing only known TV_directors
TV_director=TV_director[TV_director['Directors']!= 'Non specified']
TV_director=TV_director.groupby(['Directors']).size().reset_index(name='Total TV Show')
top_directors = pd.DataFrame(TV_director.sort_values(by=['Total TV Show'], ascending=False)).head(10)
top_directors
# Out:
#      Directors  Total TV Show
# 356        Non           2434
# 574  specified           2434
# 283        Lee              7
# 91        Chen              4
# 423    Richard              3
# 252        Ken              3
# 326    Michael              3
# 116      David              3
# 12    Alastair              3
# 79      Carlos              3

# %%
#ploting the top directots vs the total TV Show they produced
sns.barplot(y='Directors', x='Total TV Show', data=top_directors, color='red')
plt.title('Top TV Show directors')
# Out:
# Text(0.5, 1.0, 'Top TV Show directors')

# %%
# Converting the duration to an interger
Netflix_data['duration'] = Netflix_data['duration'].str.strip('min')
Netflix_data['duration'] = Netflix_data['duration'].str.strip('Seasons')
Netflix_data['duration'] = Netflix_data['duration'].str.strip('Seaso')
# Out:
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\151771412.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data['duration'] = Netflix_data['duration'].str.strip('min')
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\151771412.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data['duration'] = Netflix_data['duration'].str.strip('Seasons')
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\151771412.py:4: SettingWithCopyWarning:
# ...

# %%
#removing extra white space and converting to integer
Netflix_data['duration']=Netflix_data['duration'].str.strip('').astype('int')
Netflix_data['duration'].value_counts()
# Out:
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\1676740052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data['duration']=Netflix_data['duration'].str.strip('').astype('int')
# 1      1791
# 2       421
# 3       199
# 90      152
# 94      146
#        ...
# 189       1
# 273       1
# 212       1
# 224       1
# 191       1
# Name: duration, Length: 210, dtype: int64

# %%
#TV Show duration distribution 
Netflix_TV['duration'].hist(bins=30)
plt.xlabels=('duraction in mins')
plt.ylable=('counts')
plt.title('distribution showing the most common TV Show')
# Out:
# Text(0.5, 1.0, 'distribution showing the most common TV Show')

# %%
Netflix_movie=Netflix_data[Netflix_data['type']=='Movie']
Netflix_movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movie_director=Netflix_movie['director'].str.split(' ',expand=True).stack()
movie_director
# Out:
# 0     0      Kirsten
#       1      Johnson
# 6     0       Robert
#       1      Cullen,
#       2         José
#              ...
# 8804  1    Fleischer
# 8805  0        Peter
#       1       Hewitt
# 8806  0        Mozez
#       1        Singh
# Length: 14412, dtype: object

# %%
#Movie show distribution
Netflix_movie['duration'].hist(bins=30)
plt.xlabel('Duration in minutes')
plt.ylabel('Count')
plt.title('Distribution showing the most common movie durations');

# %%
sns.boxplot(x='duration', data=Netflix_movie)
plt.xlabel('Duration in minutes');
plt.tite('To show outliers in the duration columns')

# %%
plt.scatter(x='duration',y='type', data=Netflix_movie)
plt.xlabel('Duration in minutes');
plt.title('To show outliers in duration vs type')
# Out:
# Text(0.5, 1.0, 'To show outliers in duration vs type')

# %%
#To show release of movie after the year 2000
net=Netflix_data[Netflix_data['release_year']>2000]
df_net=pd.DataFrame(net['release_year'].value_counts())

# %%
sns.heatmap(df_net)
# Out:
# <AxesSubplot:>

# %%
#Using the matplotlib for release year 
plt.plot(df_net)

# %%
#Shwoing the most content released 
Netflix_data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_categories = {
    'TV-PG': 'Parental Guidance',
    'TV-MA': 'Mature Audience',
    'TV-Y7-FV': 'Teens',
    'TV-Y7': 'Teens',
    'TV-14': 'Teens',
    'R': 'Mature Audience',
    'TV-Y': 'General Audience',
    'NR': 'Mature Audience',
    'PG-13': 'Teens',
    'TV-G': 'General Audience',
    'PG': 'Teens',
    'G': 'General Audience',
    'UR': 'Mature Audience',
    'NC-17': 'Mature Audience'
}
Netflix_data["rating"] = Netflix_data['rating'].replace(new_categories)
Netflix_data['rating'].value_counts()
# Out:
# C:\Users\juliy\AppData\Local\Temp\ipykernel_19416\782681896.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Netflix_data["rating"] = Netflix_data['rating'].replace(new_categories)
# Mature Audience      4089
# Teens                3273
# Parental Guidance     861
# General Audience      567
# Name: rating, dtype: int64

# %%
plt.hist(x='rating', data=Netflix_data, color='yellow' )
plt.title("Count of Rating by Movie and Shows");
