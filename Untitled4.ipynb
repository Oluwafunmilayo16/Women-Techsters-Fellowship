# %%
import pandas as pd

# %%
fb_1= pd.read_csv('fifa_ranking_2022-10-06.csv')
fb_2= pd.read_csv('matches_1930_2018.csv')
fb_3=pd.read_csv('matches_2022.csv')
fb_4=pd.read_csv('world_cup.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 fb_1= pd.read_csv('fifa_ranking_2022-10-06.csv')
#       2 fb_2= pd.read_csv('matches_1930_2018.csv')
#       3 fb_3=pd.read_csv('matches_2022.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
fb_1.head()

# %%
fb_1.isnull().sum()
# Out:
# team               0
# team_code          0
# association        0
# rank               0
# previous_rank      0
# points             0
# previous_points    0
# dtype: int64

# %%
fb_2.head()
# Out:
#   home_team away_team  home_score  home_xg  home_penalty  away_score  away_xg  \
# 0    France   Croatia           4      1.1           NaN           2      1.1
# 1   Belgium   England           2      1.5           NaN           0      1.0
# 2   Croatia   England           2      1.7           NaN           1      0.6
# 3    France   Belgium           1      1.7           NaN           0      0.4
# 4    Sweden   England           0      0.5           NaN           2      1.0
#
#    away_penalty      home_manager       home_captain  ... Attendance  \
# 0           NaN  Didier Deschamps        Hugo Lloris  ...      78011
# 1           NaN  Roberto Martínez        Eden Hazard  ...      64406
# 2           NaN      Zlatko Dalić        Luka Modrić  ...      78011
# 3           NaN  Didier Deschamps        Hugo Lloris  ...      64286
# 4           NaN   Janne Andersson  Andreas Granqvist  ...      39991
#
#                                   Venue  \
# ...

# %%
fb_2.isnull().sum()
# Out:
# home_team         0
# away_team         0
# home_score        0
# home_xg         836
# home_penalty    870
# away_score        0
# away_xg         836
# away_penalty    870
# home_manager      0
# home_captain    320
# away_manager      0
# away_captain    320
# home_goals      162
# away_goals      283
# Attendance        0
# Venue             0
# Officials       255
# Date              0
# Score             0
# Referee         255
# Notes           832
# Round             0
# Host              0
# Year              0
# dtype: int64

# %%
import numpy as np
from numpy import NaN
fb_2["home_xg"].fillna(0,inplace=True),
fb_2["home_penalty"].fillna(0,inplace=True),
fb_2["away_xg"].fillna(0,inplace=True),
fb_2["away_penalty"].fillna(0,inplace=True),
fb_2["home_captain"].fillna(0,inplace=True),
fb_2["away_captain"].fillna(0,inplace=True),
fb_2["home_goals"].fillna(0,inplace=True),
fb_2["away_goals"].fillna(0,inplace=True),
fb_2["Officials"].fillna(0,inplace=True),
fb_2["Referee"].fillna(0,inplace=True),
fb_2["Notes"].fillna(0,inplace=True),
fb_2
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0           France   Croatia           4      1.1           0.0           2
# 1          Belgium   England           2      1.5           0.0           0
# 2          Croatia   England           2      1.7           0.0           1
# 3           France   Belgium           1      1.7           0.0           0
# 4           Sweden   England           0      0.5           0.0           2
# ..             ...       ...         ...      ...           ...         ...
# 895      Argentina    France           1      0.0           0.0           0
# 896     Yugoslavia    Brazil           2      0.0           0.0           1
# 897        Romania      Peru           3      0.0           0.0           1
# 898  United States   Belgium           3      0.0           0.0           0
# 899         France    Mexico           4      0.0           0.0           1
#
# ...

# %%
fb_2.isnull().sum()
# Out:
# home_team       0
# away_team       0
# home_score      0
# home_xg         0
# home_penalty    0
# away_score      0
# away_xg         0
# away_penalty    0
# home_manager    0
# home_captain    0
# away_manager    0
# away_captain    0
# home_goals      0
# away_goals      0
# Attendance      0
# Venue           0
# Officials       0
# Date            0
# Score           0
# Referee         0
# Notes           0
# Round           0
# Host            0
# Year            0
# dtype: int64

# %%
fb_3.head()
# Out:
#        home_team    away_team  home_score  home_xg  home_penalty  away_score  \
# 0          Qatar      Ecuador         0.0      0.3           NaN         2.0
# 1        England      IR Iran         6.0      2.1           NaN         2.0
# 2  United States        Wales         1.0      0.8           NaN         1.0
# 3        Senegal  Netherlands         0.0      0.9           NaN         2.0
# 4         France    Australia         4.0      4.0           NaN         1.0
#
#    away_xg  away_penalty      home_manager       home_captain  ... Attendance  \
# 0      1.2           NaN     Félix Sánchez   Hassan Al-Haydos  ...      67372
# 1      1.4           NaN  Gareth Southgate         Harry Kane  ...      45334
# 2      1.5           NaN   Gregg Berhalter        Tyler Adams  ...      43418
# 3      0.7           NaN       Aliou Cissé  Kalidou Koulibaly  ...      41721
# 4      0.5           NaN  Didier Deschamps        Hugo Lloris  ...      40875
#
# ...

# %%
fb_3.isnull().sum()
# Out:
# home_team        0
# away_team        0
# home_score       8
# home_xg          8
# home_penalty    48
# away_score       8
# away_xg          8
# away_penalty    48
# home_manager     8
# home_captain     8
# away_manager     8
# away_captain     8
# home_goals      21
# away_goals      24
# Attendance       0
# Venue            8
# Officials        8
# Date             0
# Score            8
# Referee          8
# Notes           48
# Round           48
# Host             0
# Year             0
# dtype: int64

# %%
fb_3["home_score"].fillna(0,inplace=True),
fb_3["home_xg"].fillna(0,inplace=True),
fb_3["home_penalty"].fillna(0,inplace=True),
fb_3["away_score"].fillna(0,inplace=True),
fb_3["away_xg"].fillna(0,inplace=True),
fb_3["away_penalty"].fillna(0,inplace=True),
fb_3["home_manager"].fillna(0,inplace=True),
fb_3["home_captain"].fillna(0,inplace=True),
fb_3["away_manager"].fillna(0,inplace=True),
fb_3["away_captain"].fillna(0,inplace=True),
fb_3["home_goals"].fillna(0,inplace=True),
fb_3["away_goals"].fillna(0,inplace=True),
fb_3["Venue"].fillna(0,inplace=True),
fb_3["Officials"].fillna(0,inplace=True),
fb_3["Score"].fillna(0,inplace=True),
fb_3["Referee"].fillna(0,inplace=True),
fb_3["Notes"].fillna(0,inplace=True),
fb_3["Round"].fillna(0,inplace=True),
fb_3.head()
# Out:
#        home_team    away_team  home_score  home_xg  home_penalty  away_score  \
# 0          Qatar      Ecuador         0.0      0.3           0.0         2.0
# 1        England      IR Iran         6.0      2.1           0.0         2.0
# 2  United States        Wales         1.0      0.8           0.0         1.0
# 3        Senegal  Netherlands         0.0      0.9           0.0         2.0
# 4         France    Australia         4.0      4.0           0.0         1.0
#
#    away_xg  away_penalty      home_manager       home_captain  ... Attendance  \
# 0      1.2           0.0     Félix Sánchez   Hassan Al-Haydos  ...      67372
# 1      1.4           0.0  Gareth Southgate         Harry Kane  ...      45334
# 2      1.5           0.0   Gregg Berhalter        Tyler Adams  ...      43418
# 3      0.7           0.0       Aliou Cissé  Kalidou Koulibaly  ...      41721
# 4      0.5           0.0  Didier Deschamps        Hugo Lloris  ...      40875
#
# ...

# %%
fb_3.isnull().sum()
# Out:
# home_team       0
# away_team       0
# home_score      0
# home_xg         0
# home_penalty    0
# away_score      0
# away_xg         0
# away_penalty    0
# home_manager    0
# home_captain    0
# away_manager    0
# away_captain    0
# home_goals      0
# away_goals      0
# Attendance      0
# Venue           0
# Officials       0
# Date            0
# Score           0
# Referee         0
# Notes           0
# Round           0
# Host            0
# Year            0
# dtype: int64

# %%
fb_4.head()
# Out:
#    Year          Host  Teams Champion    Runner-Up  \
# 0  2022         Qatar     32      NaN          NaN
# 1  2018        Russia     32   France      Croatia
# 2  2014        Brazil     32  Germany    Argentina
# 3  2010  South Africa     32    Spain  Netherlands
# 4  2006       Germany     32    Italy       France
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                                    NaN           0              0        0
# 1                         Harry Kane - 6     3031768          47371       64
# 2                    James Rodríguez - 6     3429873          53592       64
# 3  Wesley Sneijder, Thomas Müller... - 5     3178856          49670       64
# 4                     Miroslav Klose - 5     3352605          52384       64

# %%
fb_4.isnull().sum()
# Out:
# Year             0
# Host             0
# Teams            0
# Champion         1
# Runner-Up        1
# TopScorrer       1
# Attendance       0
# AttendanceAvg    0
# Matches          0
# dtype: int64

# %%
fb4_new = fb_4.drop(index=1, inplace=True)
fb4_new

# %%
fb4_new.head()
